# %% [markdown]
# # MAICON 베이스라인 작성 틀
# 현재는 설명 셀만 있는 템플릿입니다. 실행 코드는 미구현입니다.
# 시험에서는 제공된 Notebook 구조와 지문을 우선하고 필요한 셀을 이식하세요.

# %% [markdown]
# ## 1. 환경·규칙 확인
# 구현할 코드와 실행 결과를 아래에 추가하세요.

# %% [markdown]
# ## 2. 설정
# 구현할 코드와 실행 결과를 아래에 추가하세요.

# %% [markdown]
# ## 3. 데이터 읽기·검사
# 구현할 코드와 실행 결과를 아래에 추가하세요.

# %% [markdown]
# ## 4. 학습/검증 분리
# 구현할 코드와 실행 결과를 아래에 추가하세요.

# %% [markdown]
# ## 5. 전처리·특징 추출
# 구현할 코드와 실행 결과를 아래에 추가하세요.

# %% [markdown]
# ## 6. 모델 학습
# 구현할 코드와 실행 결과를 아래에 추가하세요.

# %% [markdown]
# ## 7. 평가·실험 비교
# 구현할 코드와 실행 결과를 아래에 추가하세요.

# %% [markdown]
# ## 8. 전체 데이터 재학습·테스트 예측
# 구현할 코드와 실행 결과를 아래에 추가하세요.

# %% [markdown]
# ## 9. 제출 CSV 검사·저장
# 구현할 코드와 실행 결과를 아래에 추가하세요.

# %% [markdown]
# ## 10. 최종 제출 확인
# 구현할 코드와 실행 결과를 아래에 추가하세요.
